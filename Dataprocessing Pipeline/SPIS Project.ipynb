# %% [markdown]
# # Correlation between heart rate variability & reported user immersion in an VR experience
#
# * Lucas Friborg Mitchell - lmitch21@student.aau.dk - Study No. 20213721

# %% [markdown]
# ## Introduction
#
# Quantifying a qualitative experience has always been a challenge. Using physiological data can help bridge the gap.
#
# This mini-project was chosen to support a main semester project. As such, the data-set and processing will be mostly the same. This paper will however go more into depth on how the data was processed.
#
# The semester project goal is to see if their is a correlation between task performance and level of immersion. An immersive VR experience is created, where the player has to make and serve cocktails for costumers. The game is split up into 3 different versions of increasing visual and sensory fidelity.
#
# The experiment is a between-subjects design, where each participant takes a 5 minute baseline measurement, followed by 1 of the 3 fidelity conditions. They then have 8 minutes to complete as many orders as possible.

# %% [markdown]
# ## Implementation
#
# The heart data was acquired, using the Blood Volume Pulse (BVP) finger clip sensor from Plux Biosignals. As such, the data was streamed from OpenSignals and recorded with [LabRecorder](https://github.com/labstreaminglayer/App-LabRecorder). This allowed for simple management of multiple data streams and synchronization.

# %%
from scipy.signal import butter, filtfilt, find_peaks
import neurokit2 as nk
import numpy as np
import pyxdf
import matplotlib.pyplot as plt
import pandas as pd
from biosppy.signals.ppg import ppg
import heartpy as hp
import glob
import re
import os
from scipy import stats
from scipy.stats import shapiro, levene, f_oneway, kruskal, mannwhitneyu
from scipy.stats import f_oneway
from itertools import combinations
import seaborn as sns
from factor_analyzer import FactorAnalyzer
import pingouin as pg
import os

debugging = True
def Trace(message):
    """
    Function to print messages with a specific format.
    """
    if (debugging):
        print(f"[Trace] {message}")
    else:
        pass

# %%
def get_gaze_data(filepath = "/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-13/sub-13_ses-13_task-Baseline/_.xdf"):
    try:
        streams, header = pyxdf.load_xdf(filepath)
    except Exception as e:
        print(f"Error loading XDF file {filepath}: {e}")
        return None, None
    gaze_stream = next((s for s in streams if s["info"]["name"][0] == "GazePointStream"), None)
    if gaze_stream:
        gaze_data = gaze_stream['time_series']
        gaze_ts = gaze_stream['time_stamps']
        return gaze_data, gaze_ts
    else:
        print(f"Warning: Gaze stream not found in {filepath}.")
        return None, None

gaze_data, gaze_ts = get_gaze_data()
# convert to DataFrame with time stamps in one axis and the object being looked at in the other axis
gaze_df = pd.DataFrame({'time': gaze_ts, 'layer': [l[0] for l in gaze_data]})
# print each unique layer
print(gaze_df["layer"].unique())
# Out:
# ['0']

# %% [markdown]
# ### Signal extraction
# The first step is extracting the data stream from the file. The .XDF file contains dictionaries, formatted as XML. So we define a path to the specific dictionary and save the signal stream and time series to a list each.

# %%
def extract_bvp_and_markers_from_xdf(filepath):
    #print(f"Attempting to load XDF: {filepath}")
    try:
        streams, header = pyxdf.load_xdf(filepath)
    except Exception as e:
        print(f"Error loading XDF file {filepath}: {e}")
        return None, None, pd.DataFrame(), {'bvp': False, 'markers': False}
    bvp_s = next((s for s in streams if s["info"]["name"][0] == "OpenSignals" and any(ch['label'][0] == 'BVP0' for ch in s['info']['desc'][0]['channels'][0]['channel'])), None)
    mark_s = next((s for s in streams if s["info"]["name"][0] == "UnityMarkers"), None)
    streams_found = {'bvp': False, 'markers': False}
    bvp_signal, bvp_ts = None, None
    df_events = pd.DataFrame()
    if bvp_s:
        bvp_data_raw = bvp_s['time_series']
        bvp_ts_raw = bvp_s['time_stamps']
        bvp_channel_idx = next((i for i, ch in enumerate(bvp_s['info']['desc'][0]['channels'][0]['channel']) if ch['label'][0] == 'BVP0'), None)
        if bvp_channel_idx is not None and bvp_data_raw.ndim == 2 and bvp_data_raw.shape[1] > bvp_channel_idx:
            bvp_signal = bvp_data_raw[:, bvp_channel_idx].astype(np.float64)
            bvp_ts = bvp_ts_raw
            streams_found['bvp'] = True
            Trace(f"BVP stream found and BVP0 channel extracted from {filepath}.")
        else:
            print(f"Warning: BVP0 channel not found or data format unexpected in OpenSignals stream for {filepath}.")
    else:
        print(f"Warning: BVP stream (OpenSignals with BVP0) not found in {filepath}.")
    if mark_s:
        markers_raw = mark_s['time_series']
        marker_ts_raw = mark_s['time_stamps']
        if len(markers_raw) > 0:
            df_events = pd.DataFrame({'time': marker_ts_raw, 'event': [m[0] for m in markers_raw]})
            streams_found['markers'] = True
            #print(f"UnityMarkers stream found in {filepath}.")
        #else:
            #print(f"Warning: UnityMarkers stream found but no event data in {filepath}.")
    return bvp_signal, bvp_ts, df_events, streams_found

# %% [markdown]
# ### Butterworth Bandpass Filter
#
# Next, is filtering the raw data with a Butterworth filter [(Butterworth, S. (1930))](https://www.changpuak.ch/electronics/downloads/On_the_Theory_of_Filter_Amplifiers.pdf). It is commonly used for filtering ECG signals, as it helps remove high frequency noise. But it also works well for other types of signals to reduce noise.
# The equation for the for a Butterworth Filter is given by:
# $$
#     G(w) = \frac{1}{\sqrt{1+w^2n}}
# $$
#
# Where $w$ is the angular frequency in radiants per second and $n$ is the number of poles in the filter. This can be modified into a bandpass filter to look like:
# $$
#     G_{BP}(w) = \frac{1}{\sqrt{1+(\frac{B(w^2-w_0^2)}{ww_0})^{2n}}}
# $$
# Here $w_0 = \sqrt{w_Lw_H}$ as the low and high frequency cutoffs, and $B = w_H - w_L$ being the bandwidth.
#
# The sample rate is based on the Nyquist frequency [(Shannon, Claude E. (1949))](https://doi.org/10.1109%2Fjrproc.1949.232969). Since we don't expect to see a heart rate of more than 200 BPM, the chosen sample rate will be 400 Hz.

# %%
def filter_bvp(signal, lowcut=0.5, highcut=8.0, fs=400):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    if high <= low:
        print(f"Warning: Highcut frequency ({highcut}Hz) is not above lowcut frequency ({lowcut}Hz) at fs={fs}Hz. Adjusting filter or skipping.")
        return signal
    try:
        b, a = butter(4, [low, high], btype='bandpass')
        filtered = filtfilt(b, a, signal)
        # plot before and after filtering for debugging
        if debugging:
            plt.figure(figsize=(12, 6))
            plt.subplot(2, 1, 1)
            plt.plot(signal, label='Original Signal')
            plt.title('Original Signal')
            plt.subplot(2, 1, 2)
            plt.plot(filtered, label='Filtered Signal', color='orange')
            plt.title('Filtered Signal')
            plt.tight_layout()
            plt.show()
        return filtered
    except ValueError as ve:
        print(f"ValueError during filtering: {ve}. Returning unfiltered signal.")
        return signal

# %% [markdown]
# ### Calculating Heart Rate Variability
#
# [HeartPy](https://pypi.org/project/heartpy/) is used to get a list of the peaks in the signal. The `hp.process()` function also further filters out very high and low heart rates, from 40 - 180 BPM.
# Then we get the time difference interval between each peak (Inter-Beat Interval). Using the guidelines outlined by [(Camm et al., 1996)](doi.org/10.1093/oxfordjournals.eurheartj.a014868) we can then calculate the HRV in the form of Root Mean Square of Successive Differences (RMSSD).

# %%
def get_hrv_metrics(bvp_segment, timestamps, fs=400):
    if len(timestamps) != len(np.unique(timestamps)):
        print(f"Warning: The input 'timestamps' (bvp_ts_raw) array itself contains duplicate values. Number of timestamps: {len(timestamps)}, Unique timestamps: {len(np.unique(timestamps))}")
    if len(bvp_segment) < fs * 10:
        print(f"Warning: Segment too short ({len(bvp_segment)/fs:.2f}s, need at least 10s), skipping HRV.")
        return pd.Series(dtype=float)
    try:
        filtered_segment = filter_bvp(bvp_segment, fs=fs)
        wd, m = hp.process(filtered_segment, sample_rate=fs, calc_freq=False, high_precision=True, clean_rr=True)
        peaks = wd.get('peaklist', [])
        if len(peaks) < 5:
            print(f"Warning: Not enough peaks found ({len(peaks)}, need at least 5), skipping HRV.")
            return pd.Series(dtype=float)
        # Ensure peak indices are integers and within bounds before indexing timestamps
        valid_peaks = []
        for p in peaks:
            try:
                p_int = int(p) # Convert to integer
                if 0 <= p_int < len(timestamps): # Check bounds
                    valid_peaks.append(p_int)
            except (ValueError, TypeError):
                print(f"Warning: Invalid peak value {p} encountered, skipping it.")

        if len(valid_peaks) < 2:
            print(f"Warning: Not enough valid peaks ({len(valid_peaks)}) after filtering and conversion. Original peaks count from heartpy: {len(peaks)}. Skipping HRV.")
            return pd.Series(dtype=float)
        peak_times_sec = timestamps[valid_peaks]
        
        # debugging time differences
        time_diffs = np.diff(peak_times_sec)
        #print(f"Time differences between BVP samples: {time_diffs}")
        Trace(f"Mean time difference: {np.mean(time_diffs)}")
        Trace(f"Standard deviation of time differences: {np.std(time_diffs)}")
        
        ibi_ms = np.diff(peak_times_sec) * 1000
        if len(ibi_ms) < 3:
            print(f"Warning: Not enough IBIs calculated ({len(ibi_ms)}), skipping HRV.")
            return pd.Series(dtype=float)
        ibi_event_times_sec = peak_times_sec[1:]
        # debugging IBI to find dublicates
        Trace(f"unique ibi event times: {len(np.unique(ibi_event_times_sec))}")
        
        hrv_indices = nk.hrv({'RRI': ibi_ms, 'RRI_Time': ibi_event_times_sec}, sampling_rate=1000)
        return hrv_indices.iloc[0]
    except Exception as e:
        print(f"Error processing segment: {e}")
        return pd.Series(dtype=float)

# %% [markdown]
# ### Running the functions
#
# Below is the loop responsible for looping through the data files and grouping the different conditions. It ends by saving a data frame with each valid subject, the condition they tested, the phase, and HRV data.

# %%
def process_subject_data(subject_id, baseline_filepath, task_filepath, nominal_srate=400):
    results_list = []
    condition_from_task_folder = "Unknown"  # Default

    # --- Get Condition from Task File's PARENT FOLDER (if it exists) ---
    if task_filepath:
        task_parent_folder_name = os.path.basename(os.path.dirname(task_filepath))
        match_cond = re.search(r'_task-([^_\s]+)', task_parent_folder_name) # More robust regex for condition
        if match_cond:
            parsed_condition = match_cond.group(1)
            # Ensure 'Baseline' from folder name doesn't become the experimental condition
            if parsed_condition.lower() != 'baseline':
                condition_from_task_folder = parsed_condition
            else:
                print(f"Warning: Task filepath {task_filepath} seems to be from a folder named '...task-Baseline...'. Experimental condition remains 'Unknown' or will be based on a non-baseline task folder if available.")
        else:
            print(f"Warning: Could not parse condition from task folder name: {task_parent_folder_name} for subject {subject_id}")

    # --- 1. Process Baseline File ---
    if baseline_filepath:
        #print(f"Processing BASELINE for subject {subject_id} (Experimental Condition: {condition_from_task_folder}) from: {os.path.basename(baseline_filepath)}")
        bvp_baseline, ts_baseline, df_events_baseline, streams_baseline = extract_bvp_and_markers_from_xdf(baseline_filepath)

        if streams_baseline['bvp'] and bvp_baseline is not None and ts_baseline is not None:
            #print(f"Calculating baseline HRV for {subject_id} (full file)...")
            hrv_baseline_metrics = get_hrv_metrics(bvp_baseline, ts_baseline, fs=nominal_srate)
            if not hrv_baseline_metrics.empty:
                baseline_res = {'ParticipantID': subject_id, 'Condition': condition_from_task_folder, 'Phase': 'Baseline'}
                baseline_res.update(hrv_baseline_metrics)
                results_list.append(baseline_res)
                print(f"Baseline HRV calculated for {subject_id}.")
            else:
                print(f"No HRV metrics obtained for baseline for subject {subject_id}.")
        else:
            print(f"Could not process BVP for baseline for subject {subject_id} from {os.path.basename(baseline_filepath)}.")
    else:
        print(f"No baseline filepath provided for subject {subject_id}.")

    # --- 2. Process Task File ---
    if task_filepath:
        #print(f"Processing TASK for subject {subject_id}, Condition: {condition_from_task_folder} from: {os.path.basename(task_filepath)}")
        bvp_task_full, ts_task_full, df_events_task, streams_task = extract_bvp_and_markers_from_xdf(task_filepath)

        if streams_task['bvp'] and bvp_task_full is not None and ts_task_full is not None:
            #print(f"Calculating task HRV for {subject_id} (full file {len(bvp_task_full)/nominal_srate:.2f}s)...")
            hrv_task_metrics = get_hrv_metrics(bvp_task_full, ts_task_full, fs=nominal_srate)
            if not hrv_task_metrics.empty:
                task_res = {'ParticipantID': subject_id, 'Condition': condition_from_task_folder, 'Phase': 'Task'}
                task_res.update(hrv_task_metrics)
                results_list.append(task_res)
                print(f"Task HRV calculated for {subject_id}.")
            else:
                print(f"No HRV metrics obtained for task phase for subject {subject_id}.")
        else:
            print(f"Could not process BVP for task for subject {subject_id} from {os.path.basename(task_filepath)}.")
    else:
        print(f"No task filepath provided for subject {subject_id}.")

    return pd.DataFrame(results_list) if results_list else pd.DataFrame()

# --- Main Processing Loop ---
all_participant_dfs = [] 
data_root_folder = os.path.join(os.getcwd(), "Test_Data")
nominal_srate_main = 400

session_folders = [f.path for f in os.scandir(data_root_folder) if f.is_dir() and re.match(r'ses-\d+', f.name)]
Trace(f"Found session folders: {session_folders}")

for session_folder_path in session_folders:
    session_name = os.path.basename(session_folder_path)
    Trace(f"\nProcessing session: {session_name}")

    potential_st_folders = [f.path for f in os.scandir(session_folder_path) if f.is_dir() and "_task-" in f.name and "sub-" in f.name]

    subject_folders_map = {}
    for st_folder_path in potential_st_folders:
        st_folder_name = os.path.basename(st_folder_path)
        match_sub = re.search(r'(sub-[^_\s]+)', st_folder_name)
        if match_sub:
            subject_id_key = match_sub.group(1)
            if subject_id_key not in subject_folders_map:
                subject_folders_map[subject_id_key] = []
            subject_folders_map[subject_id_key].append(st_folder_path)
        else:
            print(f"  Warning: Could not parse subject ID from folder name {st_folder_name} in session {session_name}.")

    Trace(f"  Found data for subjects in {session_name}: {list(subject_folders_map.keys())}")

    for subject_id_key, folders_for_subject in subject_folders_map.items():
        Trace(f"    Processing data for subject key: {subject_id_key} in session: {session_name}")

        baseline_filepath = None
        task_condition_filepath = None

        for folder_path in folders_for_subject:
            folder_name = os.path.basename(folder_path)
            xdf_files_in_folder = glob.glob(os.path.join(folder_path, "*.xdf"))

            if not xdf_files_in_folder:
                print(f"      Warning: No XDF file found in folder {folder_name}. Skipping this folder.")
                continue
            if len(xdf_files_in_folder) > 1:
                print(f"      Warning: Multiple XDF files found in {folder_name}. Using the first one: {os.path.basename(xdf_files_in_folder[0])}.")
            current_xdf_file = xdf_files_in_folder[0]

            if "_task-Baseline" in folder_name:
                if baseline_filepath:
                    print(f"      Warning: Multiple baseline folders/files found for {subject_id_key} in {session_name}. Overwriting with data from {folder_name}.")
                baseline_filepath = current_xdf_file
                Trace(f"      Found Baseline file: {os.path.basename(baseline_filepath)} in folder {folder_name}")
            elif "_task-" in folder_name:
                if task_condition_filepath:
                    print(f"      Warning: Multiple task condition folders/files found for {subject_id_key} in {session_name}. Overwriting with data from {folder_name}.")
                task_condition_filepath = current_xdf_file
                #print(f"      Found Task Condition file: {os.path.basename(task_condition_filepath)} in folder {folder_name}")

        if baseline_filepath and task_condition_filepath:
            cleaned_subject_id = re.sub(r'^sub-', '', subject_id_key)
            Trace(f"      Pair found for {cleaned_subject_id}: Baseline ({os.path.basename(baseline_filepath)}), Task ({os.path.basename(task_condition_filepath)})")
            subject_hrv_df = process_subject_data(
                subject_id=cleaned_subject_id,
                baseline_filepath=baseline_filepath,
                task_filepath=task_condition_filepath,
                nominal_srate=nominal_srate_main
            )
            if not subject_hrv_df.empty:
                all_participant_dfs.append(subject_hrv_df)
            else:
                print(f"      No HRV data generated for subject {cleaned_subject_id} in session {session_name}.")
        else:
            missing_parts = []
            if not baseline_filepath: missing_parts.append("baseline file")
            if not task_condition_filepath: missing_parts.append("task condition file")
            print(f"      Skipping subject {subject_id_key} in session {session_name} due to missing { ' and '.join(missing_parts) }.")

if not all_participant_dfs:
    print("\nNo dataframes to concatenate. Final DataFrame will be empty.")
    final_df = pd.DataFrame()
else:
    final_df = pd.concat(all_participant_dfs, ignore_index=True)
    print("\n--- Combined Results DataFrame ---")
    if not final_df.empty:
        print(final_df.head())
    else:
        print("Final DataFrame is empty after processing all subjects.")
# Out:
# [Trace] Found session folders: ['/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-10', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-11', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-12', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-13', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-01', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-02', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-03', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-04', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-05', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-06', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-07', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-08', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-09', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-16', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-17', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-18', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-19', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-20', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-21', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-22', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-23', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-24', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-25', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-26', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-14', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-15', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-27', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-28', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-29', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-30', '/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-31']
# [Trace]
# Processing session: ses-10
# [Trace]   Found data for subjects in ses-10: ['sub-10']
# [Trace]     Processing data for subject key: sub-10 in session: ses-10
# [Trace]       Found Baseline file: _.xdf in folder sub-10_ses-10_task-Baseline
# [Trace]       Pair found for 10: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-10/sub-10_ses-10_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.660764801345227
# [Trace] Standard deviation of time differences: 0.135165724170794
# [Trace] unique ibi event times: 455
# Baseline HRV calculated for 10.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-10/sub-10_ses-10_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.6616466060307714
# [Trace] Standard deviation of time differences: 0.8149021896024045
# [Trace] unique ibi event times: 824
# Task HRV calculated for 10.
# [Trace]
# Processing session: ses-11
# [Trace]   Found data for subjects in ses-11: ['sub-11']
# [Trace]     Processing data for subject key: sub-11 in session: ses-11
# [Trace]       Found Baseline file: _.xdf in folder sub-11_ses-11_task-Baseline
# [Trace]       Pair found for 11: Baseline (_.xdf), Task (_.xdf)
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-11/sub-11_ses-11_task-Baseline/_.xdf.
# Could not process BVP for baseline for subject 11 from _.xdf.
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-11/sub-11_ses-11_task-LowFi/_.xdf.
# Could not process BVP for task for subject 11 from _.xdf.
#       No HRV data generated for subject 11 in session ses-11.
# [Trace]
# Processing session: ses-12
# [Trace]   Found data for subjects in ses-12: ['sub-12']
# [Trace]     Processing data for subject key: sub-12 in session: ses-12
# [Trace]       Found Baseline file: _.xdf in folder sub-12_ses-12_task-Baseline
# [Trace]       Pair found for 12: Baseline (_.xdf), Task (_.xdf)
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-12/sub-12_ses-12_task-Baseline/_.xdf.
# Could not process BVP for baseline for subject 12 from _.xdf.
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-12/sub-12_ses-12_task-MediumFi/_.xdf.
# Could not process BVP for task for subject 12 from _.xdf.
#       No HRV data generated for subject 12 in session ses-12.
# [Trace]
# Processing session: ses-13
# [Trace]   Found data for subjects in ses-13: ['sub-13']
# [Trace]     Processing data for subject key: sub-13 in session: ses-13
# [Trace]       Found Baseline file: _.xdf in folder sub-13_ses-13_task-Baseline
# [Trace]       Pair found for 13: Baseline (_.xdf), Task (_.xdf)
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-13/sub-13_ses-13_task-Baseline/_.xdf.
# Could not process BVP for baseline for subject 13 from _.xdf.
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-13/sub-13_ses-13_task-LowFi/_.xdf.
# Could not process BVP for task for subject 13 from _.xdf.
#       No HRV data generated for subject 13 in session ses-13.
# [Trace]
# Processing session: ses-01
# [Trace]   Found data for subjects in ses-01: ['sub-1']
# [Trace]     Processing data for subject key: sub-1 in session: ses-01
# [Trace]       Found Baseline file: sub-1_ses-1_task-Baseline_.xdf in folder sub-1_ses-1_task-Baseline
# [Trace]       Pair found for 1: Baseline (sub-1_ses-1_task-Baseline_.xdf), Task (sub-1_ses-1_task-HighFi_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-01/sub-1_ses-1_task-Baseline/sub-1_ses-1_task-Baseline_.xdf.
# [Trace] Mean time difference: 0.7156792839013678
# [Trace] Standard deviation of time differences: 0.22598884695063082
# [Trace] unique ibi event times: 422
# Baseline HRV calculated for 1.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-01/sub-1_ses-1_task-HighFi/sub-1_ses-1_task-HighFi_.xdf.
# [Trace] Mean time difference: 0.7279531908014956
# [Trace] Standard deviation of time differences: 1.1888793320761193
# [Trace] unique ibi event times: 662
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 1.
# [Trace]
# Processing session: ses-02
# [Trace]   Found data for subjects in ses-02: ['sub-2']
# [Trace]     Processing data for subject key: sub-2 in session: ses-02
# [Trace]       Found Baseline file: sub-2_ses-2_task-Baseline_.xdf in folder sub-2_ses-2_task-Baseline
# [Trace]       Pair found for 2: Baseline (sub-2_ses-2_task-Baseline_.xdf), Task (sub-2_ses-1_task-HighFi_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-02/sub-2_ses-2_task-Baseline/sub-2_ses-2_task-Baseline_.xdf.
# [Trace] Mean time difference: 0.5650386538924145
# [Trace] Standard deviation of time differences: 0.0577635882648367
# [Trace] unique ibi event times: 531
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 2.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-02/sub-2_ses-2_task-HighFi/sub-2_ses-1_task-HighFi_.xdf.
# [Trace] Mean time difference: 0.620542249058682
# [Trace] Standard deviation of time differences: 0.683925109846748
# [Trace] unique ibi event times: 814
# Task HRV calculated for 2.
# [Trace]
# Processing session: ses-03
# [Trace]   Found data for subjects in ses-03: ['sub-3']
# [Trace]     Processing data for subject key: sub-3 in session: ses-03
# [Trace]       Found Baseline file: sub-3_ses-1_task-Baseline_.xdf in folder sub-3_ses-3_task-Baseline
# [Trace]       Pair found for 3: Baseline (sub-3_ses-1_task-Baseline_.xdf), Task (sub-3_ses-1_task-MediumFi_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-03/sub-3_ses-3_task-Baseline/sub-3_ses-1_task-Baseline_.xdf.
# [Trace] Mean time difference: 0.5340854849187304
# [Trace] Standard deviation of time differences: 0.16830434951938844
# [Trace] unique ibi event times: 561
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 3.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-03/sub-3_ses-3_task-MediumFi/sub-3_ses-1_task-MediumFi_.xdf.
# [Trace] Mean time difference: 0.5792577560132939
# [Trace] Standard deviation of time differences: 0.2913015874351098
# [Trace] unique ibi event times: 863
# Task HRV calculated for 3.
# [Trace]
# Processing session: ses-04
# [Trace]   Found data for subjects in ses-04: ['sub-4']
# [Trace]     Processing data for subject key: sub-4 in session: ses-04
# [Trace]       Found Baseline file: sub-4_ses-1_task-Baseline_.xdf in folder sub-4_ses-4_task-Baseline
# [Trace]       Pair found for 4: Baseline (sub-4_ses-1_task-Baseline_.xdf), Task (sub-4_ses-1_task-HighFi_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-04/sub-4_ses-4_task-Baseline/sub-4_ses-1_task-Baseline_.xdf.
# [Trace] Mean time difference: 0.5461045110697588
# [Trace] Standard deviation of time differences: 0.0711313987525694
# [Trace] unique ibi event times: 551
# Baseline HRV calculated for 4.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-04/sub-4_ses-4_task-HighFi/sub-4_ses-1_task-HighFi_.xdf.
# [Trace] Mean time difference: 0.5399137055505573
# [Trace] Standard deviation of time differences: 0.06301079971796143
# [Trace] unique ibi event times: 763
# Task HRV calculated for 4.
# [Trace]
# Processing session: ses-05
# [Trace]   Found data for subjects in ses-05: ['sub-5']
# [Trace]     Processing data for subject key: sub-5 in session: ses-05
# [Trace]       Found Baseline file: sub-5_ses-1_task-Baseline_.xdf in folder sub-5_ses-5_task-Baseline
# [Trace]       Pair found for 5: Baseline (sub-5_ses-1_task-Baseline_.xdf), Task (sub-5_ses-1_task-HighFi_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-05/sub-5_ses-5_task-Baseline/sub-5_ses-1_task-Baseline_.xdf.
# Error processing segment:
# ----------------
# Could not determine best fit for given signal. Please check the source signal.
#  Probable causes:
# - detected heart rate falls outside of bpmmin<->bpmmax constraints
# - no detectable heart rate present in signal
# - very noisy signal (consider filtering and scaling)
# If you're sure the signal contains heartrate data, consider filtering and/or scaling first.
# ----------------
#
# No HRV metrics obtained for baseline for subject 5.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-05/sub-5_ses-5_task-HighFi/sub-5_ses-1_task-HighFi_.xdf.
# [Trace] Mean time difference: 0.7283914201146331
# [Trace] Standard deviation of time differences: 1.376767560055772
# [Trace] unique ibi event times: 664
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 5.
# [Trace]
# Processing session: ses-06
# [Trace]   Found data for subjects in ses-06: ['sub-6']
# [Trace]     Processing data for subject key: sub-6 in session: ses-06
# [Trace]       Found Baseline file: _.xdf in folder sub-6_ses-6_task-Baseline
# [Trace]       Pair found for 6: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-06/sub-6_ses-6_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.7203621293523289
# [Trace] Standard deviation of time differences: 0.34260597617893374
# [Trace] unique ibi event times: 373
# Baseline HRV calculated for 6.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-06/sub-6_ses-6_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.7085979261742131
# [Trace] Standard deviation of time differences: 1.2320376453535375
# [Trace] unique ibi event times: 715
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 6.
# [Trace]
# Processing session: ses-07
# [Trace]   Found data for subjects in ses-07: ['sub-7']
# [Trace]     Processing data for subject key: sub-7 in session: ses-07
# [Trace]       Found Baseline file: _.xdf in folder sub-7_ses-7_task-Baseline
# [Trace]       Pair found for 7: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-07/sub-7_ses-7_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.7780793404083467
# [Trace] Standard deviation of time differences: 1.236922705544996
# [Trace] unique ibi event times: 387
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 7.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-07/sub-7_ses-7_task-LowFi/_.xdf.
# [Trace] Mean time difference: 0.683793287819131
# [Trace] Standard deviation of time differences: 1.286364301221754
# [Trace] unique ibi event times: 710
# Task HRV calculated for 7.
# [Trace]
# Processing session: ses-08
# [Trace]   Found data for subjects in ses-08: ['sub-8']
# [Trace]     Processing data for subject key: sub-8 in session: ses-08
# [Trace]       Found Baseline file: _.xdf in folder sub-8_ses-8_task-Baseline
# [Trace]       Pair found for 8: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-08/sub-8_ses-8_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.7580577418903159
# [Trace] Standard deviation of time differences: 1.3887960005476772
# [Trace] unique ibi event times: 392
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 8.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-08/sub-8_ses-8_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.833953731231834
# [Trace] Standard deviation of time differences: 2.763658638027661
# [Trace] unique ibi event times: 606
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 8.
# [Trace]
# Processing session: ses-09
# [Trace]   Found data for subjects in ses-09: ['sub-9']
# [Trace]     Processing data for subject key: sub-9 in session: ses-09
# [Trace]       Found Baseline file: _.xdf in folder sub-9_ses-9_task-Baseline
# [Trace]       Pair found for 9: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-09/sub-9_ses-9_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.6566866009934429
# [Trace] Standard deviation of time differences: 0.12700737967263992
# [Trace] unique ibi event times: 457
# Baseline HRV calculated for 9.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-09/sub-9_ses-9_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.6597043007715692
# [Trace] Standard deviation of time differences: 0.10084570315478025
# [Trace] unique ibi event times: 772
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 9.
# [Trace]
# Processing session: ses-16
# [Trace]   Found data for subjects in ses-16: ['sub-16']
# [Trace]     Processing data for subject key: sub-16 in session: ses-16
# [Trace]       Found Baseline file: _.xdf in folder sub-16_ses-16_task-Baseline
# [Trace]       Pair found for 16: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-16/sub-16_ses-16_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.5566838934899281
# [Trace] Standard deviation of time differences: 0.1594964259001389
# [Trace] unique ibi event times: 539
# Baseline HRV calculated for 16.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-16/sub-16_ses-16_task-LowFi/_.xdf.
# [Trace] Mean time difference: 0.5131006903620801
# [Trace] Standard deviation of time differences: 0.14962387470289942
# [Trace] unique ibi event times: 949
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 16.
# [Trace]
# Processing session: ses-17
# [Trace]   Found data for subjects in ses-17: ['sub-17']
# [Trace]     Processing data for subject key: sub-17 in session: ses-17
# [Trace]       Found Baseline file: _.xdf in folder sub-17_ses-1_task-Baseline
# [Trace]       Pair found for 17: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-17/sub-17_ses-1_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.5337847086015362
# [Trace] Standard deviation of time differences: 0.14431801755898613
# [Trace] unique ibi event times: 562
# Baseline HRV calculated for 17.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-17/sub-17_ses-1_task-LowFi/_.xdf.
# [Trace] Mean time difference: 0.5323427032015706
# [Trace] Standard deviation of time differences: 0.09456450363369033
# [Trace] unique ibi event times: 944
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 17.
# [Trace]
# Processing session: ses-18
# [Trace]   Found data for subjects in ses-18: ['sub-18']
# [Trace]     Processing data for subject key: sub-18 in session: ses-18
# [Trace]       Found Baseline file: _.xdf in folder sub-18_ses-1_task-Baseline
# [Trace]       Pair found for 18: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-18/sub-18_ses-1_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.523871634458753
# [Trace] Standard deviation of time differences: 0.26590422613891734
# [Trace] unique ibi event times: 571
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 18.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-18/sub-18_ses-1_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.6208315581717441
# [Trace] Standard deviation of time differences: 0.42189795432409344
# [Trace] unique ibi event times: 833
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 18.
# [Trace]
# Processing session: ses-19
# [Trace]   Found data for subjects in ses-19: ['sub-19']
# [Trace]     Processing data for subject key: sub-19 in session: ses-19
#       Warning: Multiple XDF files found in sub-19_ses-1_task-Baseline. Using the first one: _.xdf.
# [Trace]       Found Baseline file: _.xdf in folder sub-19_ses-1_task-Baseline
# [Trace]       Pair found for 19: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-19/sub-19_ses-1_task-Baseline/_.xdf.
# Warning: Segment too short (1.92s, need at least 10s), skipping HRV.
# No HRV metrics obtained for baseline for subject 19.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-19/sub-19_ses-1_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.540308161713047
# [Trace] Standard deviation of time differences: 0.13814025723905518
# [Trace] unique ibi event times: 984
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 19.
# [Trace]
# Processing session: ses-20
# [Trace]   Found data for subjects in ses-20: ['sub-20']
# [Trace]     Processing data for subject key: sub-20 in session: ses-20
# [Trace]       Found Baseline file: _.xdf in folder sub-20_ses-1_task-Baseline
# [Trace]       Pair found for 20: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-20/sub-20_ses-1_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.663226744678437
# [Trace] Standard deviation of time differences: 0.25673344333556025
# [Trace] unique ibi event times: 293
# Baseline HRV calculated for 20.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-20/sub-20_ses-1_task-LowFi/_.xdf.
# [Trace] Mean time difference: 0.6699342301184908
# [Trace] Standard deviation of time differences: 0.5594949052638339
# [Trace] unique ibi event times: 720
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 20.
# [Trace]
# Processing session: ses-21
# [Trace]   Found data for subjects in ses-21: ['sub-21']
# [Trace]     Processing data for subject key: sub-21 in session: ses-21
# [Trace]       Found Baseline file: _.xdf in folder sub-21_ses-1_task-Baseline
# [Trace]       Pair found for 21: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-21/sub-21_ses-1_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.645060400118788
# [Trace] Standard deviation of time differences: 0.18187847730925716
# [Trace] unique ibi event times: 463
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 21.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-21/sub-21_ses-1_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.580797928516809
# [Trace] Standard deviation of time differences: 0.12171866781287775
# [Trace] unique ibi event times: 844
# Task HRV calculated for 21.
# [Trace]
# Processing session: ses-22
# [Trace]   Found data for subjects in ses-22: ['sub-22']
# [Trace]     Processing data for subject key: sub-22 in session: ses-22
# [Trace]       Found Baseline file: _.xdf in folder sub-22_ses-22_task-Baseline
# [Trace]       Pair found for 22: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-22/sub-22_ses-22_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.598791531356951
# [Trace] Standard deviation of time differences: 0.15594405319548266
# [Trace] unique ibi event times: 502
# Baseline HRV calculated for 22.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-22/sub-22_ses-22_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.613157986959723
# [Trace] Standard deviation of time differences: 0.22654530314416466
# [Trace] unique ibi event times: 671
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 22.
# [Trace]
# Processing session: ses-23
# [Trace]   Found data for subjects in ses-23: ['sub-23']
# [Trace]     Processing data for subject key: sub-23 in session: ses-23
# [Trace]       Found Baseline file: _.xdf in folder sub-23_ses-23_task-Baseline
# [Trace]       Pair found for 23: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-23/sub-23_ses-23_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.7066327479606435
# [Trace] Standard deviation of time differences: 0.26247271256762633
# [Trace] unique ibi event times: 455
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 23.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-23/sub-23_ses-23_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.7349285358553937
# [Trace] Standard deviation of time differences: 0.9139887050697302
# [Trace] unique ibi event times: 762
# Task HRV calculated for 23.
# [Trace]
# Processing session: ses-24
# [Trace]   Found data for subjects in ses-24: ['sub-24']
# [Trace]     Processing data for subject key: sub-24 in session: ses-24
# [Trace]       Found Baseline file: _.xdf in folder sub-24_ses-24_task-Baseline
# [Trace]       Pair found for 24: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-24/sub-24_ses-24_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.627534293956997
# [Trace] Standard deviation of time differences: 0.08500596227729312
# [Trace] unique ibi event times: 478
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 24.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-24/sub-24_ses-24_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.7683934139818523
# [Trace] Standard deviation of time differences: 4.253160099061636
# [Trace] unique ibi event times: 711
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/hrv/hrv_time.py:237: RuntimeWarning: Mean of empty slice
#   avg_rri.append(np.nanmean(rri[start_idx:end_idx]))
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# Task HRV calculated for 24.
# [Trace]
# Processing session: ses-25
# [Trace]   Found data for subjects in ses-25: ['sub-25']
# [Trace]     Processing data for subject key: sub-25 in session: ses-25
# [Trace]       Found Baseline file: _.xdf in folder sub-25_ses-1_task-Baseline
# [Trace]       Pair found for 25: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-25/sub-25_ses-1_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.5914079865366646
# [Trace] Standard deviation of time differences: 0.12292452293106113
# [Trace] unique ibi event times: 506
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 25.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-25/sub-25_ses-1_task-LowFi/_.xdf.
# [Trace] Mean time difference: 0.5487587245251722
# [Trace] Standard deviation of time differences: 0.20281127307343097
# [Trace] unique ibi event times: 882
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 25.
# [Trace]
# Processing session: ses-26
# [Trace]   Found data for subjects in ses-26: ['sub-26']
# [Trace]     Processing data for subject key: sub-26 in session: ses-26
# [Trace]       Found Baseline file: _.xdf in folder sub-26_ses-1_task-Baseline
# [Trace]       Pair found for 26: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-26/sub-26_ses-1_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.6797898448336871
# [Trace] Standard deviation of time differences: 0.22591019419555924
# [Trace] unique ibi event times: 443
# Baseline HRV calculated for 26.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-26/sub-26_ses-1_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.6614796116748619
# [Trace] Standard deviation of time differences: 0.18991315691455823
# [Trace] unique ibi event times: 728
# Task HRV calculated for 26.
# [Trace]
# Processing session: ses-14
# [Trace]   Found data for subjects in ses-14: ['sub-14']
# [Trace]     Processing data for subject key: sub-14 in session: ses-14
# [Trace]       Found Baseline file: _.xdf in folder sub-14_ses-14_task-Baseline
# [Trace]       Pair found for 14: Baseline (_.xdf), Task (_.xdf)
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-14/sub-14_ses-14_task-Baseline/_.xdf.
# Could not process BVP for baseline for subject 14 from _.xdf.
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-14/sub-14_ses-14_task-MediumFi/_.xdf.
# Could not process BVP for task for subject 14 from _.xdf.
#       No HRV data generated for subject 14 in session ses-14.
# [Trace]
# Processing session: ses-15
# [Trace]   Found data for subjects in ses-15: ['sub-15']
# [Trace]     Processing data for subject key: sub-15 in session: ses-15
#       Warning: Multiple XDF files found in sub-15_ses-15_task-Baseline. Using the first one: _.xdf.
# [Trace]       Found Baseline file: _.xdf in folder sub-15_ses-15_task-Baseline
#       Warning: Multiple XDF files found in sub-15_ses-15_task-LowFi. Using the first one: _.xdf.
# [Trace]       Pair found for 15: Baseline (_.xdf), Task (_.xdf)
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-15/sub-15_ses-15_task-Baseline/_.xdf.
# Could not process BVP for baseline for subject 15 from _.xdf.
# Warning: BVP stream (OpenSignals with BVP0) not found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-15/sub-15_ses-15_task-LowFi/_.xdf.
# Could not process BVP for task for subject 15 from _.xdf.
#       No HRV data generated for subject 15 in session ses-15.
# [Trace]
# Processing session: ses-27
# [Trace]   Found data for subjects in ses-27: ['sub-27']
# [Trace]     Processing data for subject key: sub-27 in session: ses-27
# [Trace]       Found Baseline file: _.xdf in folder sub-27_ses-27_task-Baseline
# [Trace]       Pair found for 27: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-27/sub-27_ses-27_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.6369989556442074
# [Trace] Standard deviation of time differences: 0.16206304057665036
# [Trace] unique ibi event times: 465
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 27.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-27/sub-27_ses-27_task-MediumFi/_.xdf.
# [Trace] Mean time difference: 0.6053854211066049
# [Trace] Standard deviation of time differences: 0.537319346816924
# [Trace] unique ibi event times: 810
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 27.
# [Trace]
# Processing session: ses-28
# [Trace]   Found data for subjects in ses-28: ['sub-28']
# [Trace]     Processing data for subject key: sub-28 in session: ses-28
#       Warning: Multiple XDF files found in sub-28_ses-28_task-Baseline. Using the first one: _.xdf.
# [Trace]       Found Baseline file: _.xdf in folder sub-28_ses-28_task-Baseline
#       Warning: Multiple XDF files found in sub-28_ses-28_task-LowFi. Using the first one: _.xdf.
# [Trace]       Pair found for 28: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-28/sub-28_ses-28_task-Baseline/_.xdf.
# Warning: Segment too short (1.60s, need at least 10s), skipping HRV.
# No HRV metrics obtained for baseline for subject 28.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-28/sub-28_ses-28_task-LowFi/_.xdf.
# Error processing segment:
# ----------------
# Could not determine best fit for given signal. Please check the source signal.
#  Probable causes:
# - detected heart rate falls outside of bpmmin<->bpmmax constraints
# - no detectable heart rate present in signal
# - very noisy signal (consider filtering and scaling)
# If you're sure the signal contains heartrate data, consider filtering and/or scaling first.
# ----------------
#
# No HRV metrics obtained for task phase for subject 28.
#       No HRV data generated for subject 28 in session ses-28.
# [Trace]
# Processing session: ses-29
# [Trace]   Found data for subjects in ses-29: ['sub-29']
# [Trace]     Processing data for subject key: sub-29 in session: ses-29
# [Trace]       Found Baseline file: _.xdf in folder sub-29_ses-29_task-Baseline
# [Trace]       Pair found for 29: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-29/sub-29_ses-29_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.5236726452886307
# [Trace] Standard deviation of time differences: 0.029376236531313726
# [Trace] unique ibi event times: 573
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 29.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-29/sub-29_ses-29_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.5594990194609895
# [Trace] Standard deviation of time differences: 0.22523805935424426
# [Trace] unique ibi event times: 975
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 29.
# [Trace]
# Processing session: ses-30
# [Trace]   Found data for subjects in ses-30: ['sub-30']
# [Trace]     Processing data for subject key: sub-30 in session: ses-30
# [Trace]       Found Baseline file: _.xdf in folder sub-30_ses-30_task-Baseline
# [Trace]       Pair found for 30: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-30/sub-30_ses-30_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.5966584363546141
# [Trace] Standard deviation of time differences: 0.12685836291246702
# [Trace] unique ibi event times: 503
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 30.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-30/sub-30_ses-30_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.6049291512994492
# [Trace] Standard deviation of time differences: 1.514298459061127
# [Trace] unique ibi event times: 849
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Task HRV calculated for 30.
# [Trace]
# Processing session: ses-31
# [Trace]   Found data for subjects in ses-31: ['sub-31']
# [Trace]     Processing data for subject key: sub-31 in session: ses-31
# [Trace]       Found Baseline file: _.xdf in folder sub-31_ses-31_task-Baseline
# [Trace]       Pair found for 31: Baseline (_.xdf), Task (_.xdf)
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-31/sub-31_ses-31_task-Baseline/_.xdf.
# [Trace] Mean time difference: 0.6012915930312219
# [Trace] Standard deviation of time differences: 0.10265937801184219
# [Trace] unique ibi event times: 499
# /home/mitchell/Documents/Projects/P8-Project/.venv/lib64/python3.13/site-packages/neurokit2/signal/signal_interpolate.py:117: NeuroKitWarning: Duplicate x values detected. Averaging their corresponding y values.
#   warn(
# Baseline HRV calculated for 31.
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-31/sub-31_ses-31_task-HighFi/_.xdf.
# [Trace] Mean time difference: 0.5870864675086978
# [Trace] Standard deviation of time differences: 0.37286578536473386
# [Trace] unique ibi event times: 876
# Task HRV calculated for 31.
#
# --- Combined Results DataFrame ---
#   ParticipantID Condition     Phase  HRV_MeanNN     HRV_SDNN  HRV_SDANN1  \
# 0            10  MediumFi  Baseline  660.764801   135.314503   31.175987
# 1            10  MediumFi      Task  661.646606   815.397120  163.615276
# 2             1    HighFi  Baseline  715.679284   226.257083   48.481917
# 3             1    HighFi      Task  727.953191  1189.775585  273.490521
# 4             2    HighFi  Baseline  565.038654    57.817954   16.013175
#
#    HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  HRV_SDANN5  ...  HRV_SampEn  \
# 0  123.251099   17.586581  124.454787         NaN  ...    0.748622
# 1  525.514743   87.186293  544.865326         NaN  ...    0.260511
# 2  220.196165   40.496413  220.077430         NaN  ...    0.637484
# 3  930.099612  110.209036  989.813782         NaN  ...    0.284032
# 4   49.148874   19.703470   52.108503         NaN  ...    0.697417
#
#    HRV_ShanEn  HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD  \
# 0    7.325301     0.637896  1.329089   1.402479    1.777499  1.138006
# 1    8.424820     0.382497  0.166088   0.604864    0.493683  0.092566
# 2    7.536371     0.649614  1.295178   1.266539    1.320495  1.006142
# 3    7.797438     0.358562  0.241225   0.538838    0.453044  0.127725
# 4    6.874117     0.543857  1.232718   1.381905    1.749154  0.803736
#
#     HRV_HFD   HRV_KFD   HRV_LZC
# 0  1.635342  2.600628  0.795645
# 1  1.937010  1.463265  0.963948
# 2  1.855288  3.436129  0.785312
# 3  1.961610  1.560995  0.776547
# 4  1.429828  1.746135  0.510636
#
# [5 rows x 94 columns]

# %%
# Check a single subject's bvp stream to see if time stamps are evenly spaced
# Used for debugging
def check_bvp_timestamps(filepath):
    bvp_signal, ts, _, streams_found = extract_bvp_and_markers_from_xdf(filepath)
    if streams_found['bvp'] and bvp_signal is not None and ts is not None:
        print(f"BVP stream found in {filepath}.")
        time_diffs = np.diff(ts)
        print(f"Time differences between BVP samples: {time_diffs}")
        print(f"Mean time difference: {np.mean(time_diffs)}")
        print(f"Standard deviation of time differences: {np.std(time_diffs)}")
    else:
        print(f"No BVP stream found in {filepath}.")
check_bvp_timestamps("/home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-27/sub-27_ses-27_task-MediumFi/_.xdf")
# Out:
# [Trace] BVP stream found and BVP0 channel extracted from /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-27/sub-27_ses-27_task-MediumFi/_.xdf.
# BVP stream found in /home/mitchell/Documents/Projects/P8-Project/Dataprocessing Pipeline/Test_Data/ses-27/sub-27_ses-27_task-MediumFi/_.xdf.
# Time differences between BVP samples: [0.0024997  0.0024997  0.0024997  ... 0.00249975 0.00249975 0.00249975]
# Mean time difference: 0.002533121224245887
# Standard deviation of time differences: 0.021291432581365042

# %% [markdown]
# ## Statistical Model
#
# With the DataFrame (`final_df`) containing HRV metrics for each participant, condition, and phase, we can compare the baseline vs task across the conditions.
#
# A Linear Mixed-Effects Model (LMM) is used here. It allows us to model:
# - **Fixed Effects:** The average effects of Phase (Baseline vs. Task) and Condition (LowFi, MedFi, HighFi), and their interaction (Phase * Condition).
# - **Random Effects:** The variability between participants. They each have their own baseline level of the HRV metric unique to them, which is modeled as a random intercept (~1 ParticipantID).

# %%
import statsmodels.formula.api as smf

# Check if final_df exists and has data
if 'final_df' in locals() and not final_df.empty and 'HRV_RMSSD' in final_df.columns:
    # Ensure necessary columns are not all NaN
    if final_df[['HRV_RMSSD', 'Phase', 'Condition', 'ParticipantID']].isnull().all().any():
        print("Warning: One or more critical columns contain only NaN values. Cannot run model.")
    else: 
        # Remove rows with NaN in the outcome variable or predictors
        model_df = final_df.dropna(subset=['HRV_RMSSD', 'Phase', 'Condition', 'ParticipantID'])
        
        if model_df.empty:
            print("Warning: No valid data remaining after removing NaNs. Cannot run model.")
        else:
            #print("\n--- Inspecting model_df before fitting LMM ---")
            #print(model_df.info())

            # Print a few rows to see actual values
            print("\n--- Fitting Linear Mixed-Effects Model for HRV_RMSSD ---")
            # Ensure ParticipantID, Phase, and Condition are appropriate types
            model_df['ParticipantID'] = model_df['ParticipantID'].astype('category')
            model_df['Phase'] = model_df['Phase'].astype('category')
            model_df['Condition'] = model_df['Condition'].astype('category')
            
            # Define the model formula for fixed effects
            fixed_effects_formula = "HRV_RMSSD ~ C(Phase) * C(Condition)"
            # Define the random effects formula (random intercept for ParticipantID)
            random_effects_formula = "~1"
            
            try:
                # Fit the model using re_formula for random effects
                model = smf.mixedlm(fixed_effects_formula, 
                                  model_df, 
                                  groups=model_df["ParticipantID"], 
                                  re_formula=random_effects_formula)
                result = model.fit()
                
                # Print the summary
                print(result.summary())
            except Exception as e:
                print(f"Error fitting model: {e}")
                print("\nPlease check data structure and variability.")
                print("Model DataFrame head:")
                print(model_df.head())
else:
    print("Skipping statistical analysis: 'final_df' not created or is empty or missing 'HRV_RMSSD' column.")
# Out:
# --- Fitting Linear Mixed-Effects Model for HRV_RMSSD ---
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                        MixedLM             Dependent Variable:             HRV_RMSSD
# No. Observations:             48                  Method:                         REML
# No. Groups:                   25                  Scale:                          750113.3363
# Min. group size:              1                   Log-Likelihood:                 -355.5499
# Max. group size:              2                   Converged:                      Yes
# Mean group size:              1.9
# ---------------------------------------------------------------------------------------------
#                                             Coef.    Std.Err.   z    P>|z|   [0.025   0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                    366.508  304.340  1.204 0.228  -229.988  963.004
# C(Phase)[T.Task]                            1279.945  363.676  3.519 0.000   567.153 1992.737
# C(Condition)[T.LowFi]                        185.476  545.472  0.340 0.734  -883.628 1254.581
# C(Condition)[T.MediumFi]                    -125.713  487.835 -0.258 0.797 -1081.853  830.427
# C(Phase)[T.Task]:C(Condition)[T.LowFi]     -1176.270  657.500 -1.789 0.074 -2464.945  112.405
# C(Phase)[T.Task]:C(Condition)[T.MediumFi]   -888.552  580.583 -1.530 0.126 -2026.473  249.369
# Group Var                                 274467.148  322.586
# =============================================================================================

# %% [markdown]
# # Results
#
# This mini-project aimed to create a pipeline for processing BVP data to extract HRV metrics; furthermore exploring the potential correlations with the user experience in a VR experience. The data was extracted using a Butterworth bandpass filter and utilized HeartPy and NeuoroKit2 to calculate the HRV RMSSD.
#
# A LMM was used to analyze the data, considering the fixed effects of phase as baseline vs task, conditions as LowFi, MedFi, HighFi, and their interaction. While still accounting for random variability between participants.
#
# The model showed indications that baseline RMSSD levels were comparable across the different conditions, which was expected. While not statistically significant at the p < 0.05 threshold, the interaction `C(Phase)[T.Task]:C(condition)[T.LowFi]` (HighFi reference group) saw a trend level of p = 0.074, where the LowFi condition might evoke a different physiological response. Specifically, the results hinted that the LowFi group experienced a smaller change in RMSSD during their task compared to the HighFi group.
